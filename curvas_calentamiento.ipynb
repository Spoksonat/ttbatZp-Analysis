# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
tiempoV_corto = [0,40,60,100,120,180,300,340,480,500,650,670,900]
tiempoI_corto = [0,60,70,120,180,300,340,480,540,650,730,900]
voltaje_corto = [0,16.61, 16.61, 33.23, 33.23, 50.46, 50.46, 67.69, 67.69, 75.08, 75.08, 80, 80]
corriente_corto = [0,0,5,5,15,15,25,25,37.5,37.5,50,50]

plt.figure(figsize=(15,10))
plt.plot(tiempoV_corto, voltaje_corto)

plt.figure(figsize=(15,10))
plt.plot(tiempoI_corto, corriente_corto)

# %%
import datetime

for i, time in enumerate(tiempoV_corto):
    print("Votaje, Tiempo V: ", voltaje_corto[i] ,str(datetime.timedelta(seconds=time)))
# Out:
# Votaje, Tiempo V:  0 0:00:00
# Votaje, Tiempo V:  16.61 0:00:40
# Votaje, Tiempo V:  16.61 0:01:00
# Votaje, Tiempo V:  33.23 0:01:40
# Votaje, Tiempo V:  33.23 0:02:00
# Votaje, Tiempo V:  50.46 0:03:00
# Votaje, Tiempo V:  50.46 0:05:00
# Votaje, Tiempo V:  67.69 0:05:40
# Votaje, Tiempo V:  67.69 0:08:00
# Votaje, Tiempo V:  75.08 0:08:20
# Votaje, Tiempo V:  75.08 0:10:50
# Votaje, Tiempo V:  80 0:11:10
# Votaje, Tiempo V:  80 0:15:00

# %%
for i, time in enumerate(tiempoI_corto):
    print("Corriente, Tiempo I: ", corriente_corto[i] ,str(datetime.timedelta(seconds=time)))
# Out:
# Corriente, Tiempo V:  0 0:00:00
# Corriente, Tiempo V:  0 0:01:00
# Corriente, Tiempo V:  5 0:01:10
# Corriente, Tiempo V:  5 0:02:00
# Corriente, Tiempo V:  15 0:03:00
# Corriente, Tiempo V:  15 0:05:00
# Corriente, Tiempo V:  25 0:05:40
# Corriente, Tiempo V:  25 0:08:00
# Corriente, Tiempo V:  37.5 0:09:00
# Corriente, Tiempo V:  37.5 0:10:50
# Corriente, Tiempo V:  50 0:12:10
# Corriente, Tiempo V:  50 0:15:00

# %%
tiempoV_larga = [0,60,700,760,2480,2540,3600,3660,5480,5540,6600,6660,7200]
tiempoI_larga = [0,60,700,760,2480,2540,3600,3660,5480,5540,6600,6660,7200]

plt.figure(figsize=(15,10))
plt.plot(tiempoV_larga, voltaje_corto)

# %%
for i, time in enumerate(tiempoV_larga):
    print("Votaje, Tiempo V: ", voltaje_corto[i] ,str(datetime.timedelta(seconds=time)))
# Out:
# Votaje, Tiempo V:  0 0:00:00
# Votaje, Tiempo V:  16.61 0:01:00
# Votaje, Tiempo V:  16.61 0:11:40
# Votaje, Tiempo V:  33.23 0:12:40
# Votaje, Tiempo V:  33.23 0:41:20
# Votaje, Tiempo V:  50.46 0:42:20
# Votaje, Tiempo V:  50.46 1:00:00
# Votaje, Tiempo V:  67.69 1:01:00
# Votaje, Tiempo V:  67.69 1:31:20
# Votaje, Tiempo V:  75.08 1:32:20
# Votaje, Tiempo V:  75.08 1:50:00
# Votaje, Tiempo V:  80 1:51:00
# Votaje, Tiempo V:  80 2:00:00

# %%
import numpy as np 

row = np.array(["bjets[0].Pt()", "bjets[1].Pt()", "bjets[2].Pt()", "bjets[3].Pt()", "(bjets[0].Eta() - bjets[1].Eta())", "(bjets[0].Eta() - bjets[2].Eta())", 
"(bjets[0].Eta() - bjets[3].Eta())", "(bjets[1].Eta() - bjets[2].Eta())", "(bjets[1].Eta() - bjets[3].Eta())", "(bjets[2].Eta() - bjets[3].Eta())", "bjets[0].DeltaPhi(bjets[1])", 
"bjets[0].DeltaPhi(bjets[2])", "bjets[0].DeltaPhi(bjets[3])", "bjets[1].DeltaPhi(bjets[2])", "bjets[1].DeltaPhi(bjets[3])", "bjets[2].DeltaPhi(bjets[3])", "bjets[0].DeltaR(bjets[1])", 
"bjets[0].DeltaR(bjets[2])", "bjets[0].DeltaR(bjets[3])", "bjets[1].DeltaR(bjets[2])", "bjets[1].DeltaR(bjets[3])", "bjets[2].DeltaR(bjets[3])", "MET.Pt()", 
"np.sum(np.array(leptons)).Pt()", "(leptons_tot + MET).Mt()", "(bjets[0] + bjets[1]).M()", "(bjets[0] + bjets[2]).M()", "(bjets[0] + bjets[3]).M()", "(bjets[1] + bjets[2]).M()",
"(bjets[1] + bjets[3]).M()", "(bjets[2] + bjets[3]).M()", "(bjets[0] + leptons_tot + MET).Mt()", "(bjets[1] + leptons_tot + MET).Mt()", "(bjets[2] + leptons_tot + MET).Mt()",
"(bjets[3] + leptons_tot + MET).Mt()", "(jets[0] + jets[1]).M()", "jets[0].Pt()", "jets[1].Pt()", "jets[0].DeltaR(jets[1])", "bjets[0].DeltaR(leptons_tot)", "bjets[1].DeltaR(leptons_tot)",
"bjets[2].DeltaR(leptons_tot)", "bjets[3].DeltaR(leptons_tot)", "bjets[0].DeltaPhi(leptons_tot)", "bjets[1].DeltaPhi(leptons_tot)", "bjets[2].DeltaPhi(leptons_tot)", 
"bjets[3].DeltaPhi(leptons_tot)"])

for i, elem in enumerate(row):
    print(i, elem)
# Out:
# 0 bjets[0].Pt()
# 1 bjets[1].Pt()
# 2 bjets[2].Pt()
# 3 bjets[3].Pt()
# 4 (bjets[0].Eta() - bjets[1].Eta())
# 5 (bjets[0].Eta() - bjets[2].Eta())
# 6 (bjets[0].Eta() - bjets[3].Eta())
# 7 (bjets[1].Eta() - bjets[2].Eta())
# 8 (bjets[1].Eta() - bjets[3].Eta())
# 9 (bjets[2].Eta() - bjets[3].Eta())
# 10 bjets[0].DeltaPhi(bjets[1])
# 11 bjets[0].DeltaPhi(bjets[2])
# 12 bjets[0].DeltaPhi(bjets[3])
# 13 bjets[1].DeltaPhi(bjets[2])
# 14 bjets[1].DeltaPhi(bjets[3])
# 15 bjets[2].DeltaPhi(bjets[3])
# 16 bjets[0].DeltaR(bjets[1])
# 17 bjets[0].DeltaR(bjets[2])
# 18 bjets[0].DeltaR(bjets[3])
# 19 bjets[1].DeltaR(bjets[2])
# 20 bjets[1].DeltaR(bjets[3])
# 21 bjets[2].DeltaR(bjets[3])
# 22 MET.Pt()
# 23 np.sum(np.array(leptons)).Pt()
# 24 (leptons_tot + MET).Mt()
# 25 (bjets[0] + bjets[1]).M()
# 26 (bjets[0] + bjets[2]).M()
# 27 (bjets[0] + bjets[3]).M()
# 28 (bjets[1] + bjets[2]).M()
# 29 (bjets[1] + bjets[3]).M()
# 30 (bjets[2] + bjets[3]).M()
# 31 (bjets[0] + leptons_tot + MET).Mt()
# ...

# %%
var_350 = [["pT b1      ",   0.1058],
["M b1 b2    ",   0.0461],
["M b1 b3    ",   0.0403],
["dR b1 b2   ",   0.0288],
["pT b2      ",   0.0258],
["M b1 b4    ",   0.0251],
["M b2 b3    ",   0.0240],
["pT j2      ",   0.0230],
["pT b3      ",   0.0229],
["pT j1      ",   0.0218],
["dR b1 b3   ",   0.0216],
["pT l       ",   0.0216],
["MET        ",   0.0204],
["dR b1 l    ",   0.0201],
["M b2 b4    ",   0.0197],
["dR b2 l    ",   0.0196],
["pT b4      ",   0.0194],
["dR b1 b4   ",   0.0193],
["M j1 j2    ",   0.0189],
["sdEta b1 b2",   0.0187],
["M b3 b4    ",   0.0185],
["MT l MET   ",   0.0184],
["sdEta b1 b3",   0.0179],
["MT b2 l MET",   0.0176],
["sdPhi b1 b3",   0.0171],
["dR b2 b4   ",   0.0170],
["sdPhi b1 b4",   0.0168],
["sdEta b3 b4",   0.0167],
["dR b4 l    ",   0.0167],
["sdEta b1 b4",   0.0165],
["sdEta b2 b3",   0.0164],
["dR b3 b4   ",   0.0164],
["sdPhi b2 b3",   0.0163],
["sdEta b2 b4",   0.0163],
["sdPhi b3 b4",   0.0160],
["sdPhi b1 b2",   0.0160],
["dR b3 l    ",   0.0160],
["MT b4 l MET",   0.0158],
["dR b2 b3   ",   0.0157],
["sdPhi b4 l ",   0.0156],
["sdPhi b2 b4",   0.0154],
["dR j1 j2   ",   0.0154],
["sdPhi b2 l ",   0.0148],
["sdPhi b3 l ",   0.0145],
["MT b1 l MET",   0.0145],
["sdPhi b1 l ",   0.0144],
["MT b3 l MET",   0.0143]]


var_1000 = [["pT b1      ",   0.3591],
["M b1 b2    ",   0.0628],
["pT j1      ",   0.0477],
["M b1 b3    ",   0.0293],
["pT b2      ",   0.0243],
["M b1 b4    ",   0.0176],
["pT b3      ",   0.0155],
["dR b1 b2   ",   0.0146],
["pT j2      ",   0.0144],
["M b2 b3    ",   0.0137],
["sdEta b1 b2",   0.0134],
["dR b1 l    ",   0.0130],
["dR b1 b3   ",   0.0129],
["dR b2 l    ",   0.0128],
["M b2 b4    ",   0.0124],
["sdEta b1 b3",   0.0124],
["pT l       ",   0.0123],
["pT b4      ",   0.0121],
["M j1 j2    ",   0.0121],
["sdEta b3 b4",   0.0120],
["dR b1 b4   ",   0.0119],
["M b3 b4    ",   0.0115],
["MT l MET   ",   0.0113],
["dR b2 b3   ",   0.0112],
["dR b3 l    ",   0.0108],
["sdPhi b1 b2",   0.0108],
["dR b3 b4   ",   0.0107],
["sdPhi b1 l ",   0.0106],
["MT b3 l MET",   0.0106],
["sdPhi b1 b3",   0.0106],
["dR b2 b4   ",   0.0106],
["dR b4 l    ",   0.0105],
["MT b4 l MET",   0.0105],
["sdEta b2 b4",   0.0103],
["MET        ",   0.0102],
["sdPhi b3 b4",   0.0102],
["sdPhi b1 b4",   0.0101],
["dR j1 j2   ",   0.0099],
["sdPhi b3 l ",   0.0098],
["MT b1 l MET",   0.0098],
["sdEta b1 b4",   0.0096],
["sdPhi b2 b3",   0.0096],
["sdPhi b2 l ",   0.0094],
["sdPhi b4 l ",   0.0093],
["MT b2 l MET",   0.0089],
["sdEta b2 b3",   0.0087],
["sdPhi b2 b4",   0.0083]]


var_3000 = [["pT b1      ",   0.5627],
["pT j1      ",   0.0784],
["M b1 b2    ",   0.0553],
["M j1 j2    ",   0.0176],
["M b1 b3    ",   0.0129],
["pT j2      ",   0.0116],
["MT b3 l MET",   0.0114],
["dR b1 l    ",   0.0099],
["pT b2      ",   0.0099],
["M b1 b4    ",   0.0098],
["sdEta b1 b3",   0.0096],
["M b2 b3    ",   0.0093],
["dR b1 b4   ",   0.0087],
["sdEta b1 b4",   0.0084],
["pT b3      ",   0.0083],
["sdPhi b1 b3",   0.0082],
["M b2 b4    ",   0.0080],
["MT b2 l MET",   0.0079],
["dR b1 b2   ",   0.0075],
["sdPhi b2 b3",   0.0070],
["sdPhi b3 b4",   0.0069],
["dR b2 b3   ",   0.0067],
["MET        ",   0.0066],
["sdPhi b1 b2",   0.0064],
["MT b4 l MET",   0.0061],
["pT b4      ",   0.0058],
["sdPhi b1 l ",   0.0058],
["dR b2 l    ",   0.0055],
["dR b2 b4   ",   0.0054],
["sdEta b3 b4",   0.0053],
["sdPhi b4 l ",   0.0053],
["dR b3 l    ",   0.0052],
["dR j1 j2   ",   0.0052],
["sdPhi b1 b4",   0.0050],
["sdPhi b2 b4",   0.0049],
["MT l MET   ",   0.0048],
["M b3 b4    ",   0.0047],
["dR b3 b4   ",   0.0045],
["dR b4 l    ",   0.0045],
["sdEta b2 b4",   0.0044],
["MT b1 l MET",   0.0044],
["sdPhi b3 l ",   0.0044],
["sdEta b1 b2",   0.0044],
["dR b1 b3   ",   0.0041],
["sdEta b2 b3",   0.0039],
["sdPhi b2 l ",   0.0037],
["pT l       ",   0.0037]]

def name(list):
    return list[0]

var_350.sort(key=name)
var_1000.sort(key=name)
var_3000.sort(key=name)

# %%
print(var_350)
print(var_1000)
print(var_3000)
# Out:
# [['M b1 b2    ', 0.0461], ['M b1 b3    ', 0.0403], ['M b1 b4    ', 0.0251], ['M b2 b3    ', 0.024], ['M b2 b4    ', 0.0197], ['M b3 b4    ', 0.0185], ['M j1 j2    ', 0.0189], ['MET        ', 0.0204], ['MT b1 l MET', 0.0145], ['MT b2 l MET', 0.0176], ['MT b3 l MET', 0.0143], ['MT b4 l MET', 0.0158], ['MT l MET   ', 0.0184], ['dR b1 b2   ', 0.0288], ['dR b1 b3   ', 0.0216], ['dR b1 b4   ', 0.0193], ['dR b1 l    ', 0.0201], ['dR b2 b3   ', 0.0157], ['dR b2 b4   ', 0.017], ['dR b2 l    ', 0.0196], ['dR b3 b4   ', 0.0164], ['dR b3 l    ', 0.016], ['dR b4 l    ', 0.0167], ['dR j1 j2   ', 0.0154], ['pT b1      ', 0.1058], ['pT b2      ', 0.0258], ['pT b3      ', 0.0229], ['pT b4      ', 0.0194], ['pT j1      ', 0.0218], ['pT j2      ', 0.023], ['pT l       ', 0.0216], ['sdEta b1 b2', 0.0187], ['sdEta b1 b3', 0.0179], ['sdEta b1 b4', 0.0165], ['sdEta b2 b3', 0.0164], ['sdEta b2 b4', 0.0163], ['sdEta b3 b4', 0.0167], ['sdPhi b1 b2', 0.016], ['sdPhi b1 b3', 0.0171], ['sdPhi b1 b4', 0.0168], ['
# ...

# %%
count = 0
for i in range(len(var_350)):
    if(var_350[i][0] == var_1000[i][0] and var_350[i][0] == var_3000[i][0]):
        count = count + 1

print(count)
# Out:
# 47

# %%
vars = []
for i in range(len(var_350)):
    vars.append([var_350[i][0], var_350[i][1]*var_1000[i][1]*var_3000[i][1]])

print(vars)
# Out:
# [['M b1 b2    ', 0.00016009792400000002], ['M b1 b3    ', 1.5232191000000002e-05], ['M b1 b4    ', 4.3292480000000005e-06], ['M b2 b3    ', 3.05784e-06], ['M b2 b4    ', 1.95424e-06], ['M b3 b4    ', 9.99925e-07], ['M j1 j2    ', 4.0249440000000006e-06], ['MET        ', 1.3733280000000002e-06], ['MT b1 l MET', 6.252400000000001e-07], ['MT b2 l MET', 1.2374560000000003e-06], ['MT b3 l MET', 1.7280120000000001e-06], ['MT b4 l MET', 1.0119900000000002e-06], ['MT l MET   ', 9.980159999999998e-07], ['dR b1 b2   ', 3.1535999999999998e-06], ['dR b1 b3   ', 1.1424240000000003e-06], ['dR b1 b4   ', 1.998129e-06], ['dR b1 l    ', 2.58687e-06], ['dR b2 b3   ', 1.178128e-06], ['dR b2 b4   ', 9.730800000000001e-07], ['dR b2 l    ', 1.3798399999999997e-06], ['dR b3 b4   ', 7.896599999999999e-07], ['dR b3 l    ', 8.985600000000001e-07], ['dR b4 l    ', 7.890749999999999e-07], ['dR j1 j2   ', 7.92792e-07], ['pT b1      ', 0.021378537305999996], ['pT b2      ', 6.206706e-06], ['pT b3      ', 2.946085
# ...

# %%
def prob(list):
    return list[1]

vars.sort(reverse=True, key=prob)
print(vars)
# Out:
# [['pT b1      ', 0.021378537305999996], ['M b1 b2    ', 0.00016009792400000002], ['pT j1      ', 8.1525024e-05], ['M b1 b3    ', 1.5232191000000002e-05], ['pT b2      ', 6.206706e-06], ['M b1 b4    ', 4.3292480000000005e-06], ['M j1 j2    ', 4.0249440000000006e-06], ['pT j2      ', 3.841919999999999e-06], ['dR b1 b2   ', 3.1535999999999998e-06], ['M b2 b3    ', 3.05784e-06], ['pT b3      ', 2.946085e-06], ['dR b1 l    ', 2.58687e-06], ['sdEta b1 b3', 2.1308159999999996e-06], ['dR b1 b4   ', 1.998129e-06], ['M b2 b4    ', 1.95424e-06], ['MT b3 l MET', 1.7280120000000001e-06], ['sdPhi b1 b3', 1.486332e-06], ['dR b2 l    ', 1.3798399999999997e-06], ['MET        ', 1.3733280000000002e-06], ['pT b4      ', 1.3614919999999998e-06], ['sdEta b1 b4', 1.33056e-06], ['MT b2 l MET', 1.2374560000000003e-06], ['dR b2 b3   ', 1.178128e-06], ['dR b1 b3   ', 1.1424240000000003e-06], ['sdPhi b3 b4', 1.12608e-06], ['sdPhi b1 b2', 1.1059200000000002e-06], ['sdEta b1 b2', 1.1025520000000002e-06], ['sdPhi
# ...

# %%
for i in range(20):
    print(vars[i][0], vars[i][1])
# Out:
# pT b1       0.021378537305999996
# M b1 b2     0.00016009792400000002
# pT j1       8.1525024e-05
# M b1 b3     1.5232191000000002e-05
# pT b2       6.206706e-06
# M b1 b4     4.3292480000000005e-06
# M j1 j2     4.0249440000000006e-06
# pT j2       3.841919999999999e-06
# dR b1 b2    3.1535999999999998e-06
# M b2 b3     3.05784e-06
# pT b3       2.946085e-06
# dR b1 l     2.58687e-06
# sdEta b1 b3 2.1308159999999996e-06
# dR b1 b4    1.998129e-06
# M b2 b4     1.95424e-06
# MT b3 l MET 1.7280120000000001e-06
# sdPhi b1 b3 1.486332e-06
# dR b2 l     1.3798399999999997e-06
# MET         1.3733280000000002e-06
# pT b4       1.3614919999999998e-06

# %%
indxs = [0, 25, 36, 26, 1, 27, 35, 37, 16, 28, 2, 39, 5, 18, 29, 33, 11, 40, 22, 3]

"""
0 bjets[0].Pt()
1 bjets[1].Pt()
2 bjets[2].Pt()
3 bjets[3].Pt()
4 (bjets[0].Eta() - bjets[1].Eta())
5 (bjets[0].Eta() - bjets[2].Eta())
6 (bjets[0].Eta() - bjets[3].Eta())
7 (bjets[1].Eta() - bjets[2].Eta())
8 (bjets[1].Eta() - bjets[3].Eta())
9 (bjets[2].Eta() - bjets[3].Eta())
10 bjets[0].DeltaPhi(bjets[1])
11 bjets[0].DeltaPhi(bjets[2])
12 bjets[0].DeltaPhi(bjets[3])
13 bjets[1].DeltaPhi(bjets[2])
14 bjets[1].DeltaPhi(bjets[3])
15 bjets[2].DeltaPhi(bjets[3])
16 bjets[0].DeltaR(bjets[1])
17 bjets[0].DeltaR(bjets[2])
18 bjets[0].DeltaR(bjets[3])
19 bjets[1].DeltaR(bjets[2])
20 bjets[1].DeltaR(bjets[3])
21 bjets[2].DeltaR(bjets[3])
22 MET.Pt()
23 np.sum(np.array(leptons)).Pt()
24 (leptons_tot + MET).Mt()
25 (bjets[0] + bjets[1]).M()
26 (bjets[0] + bjets[2]).M()
27 (bjets[0] + bjets[3]).M()
28 (bjets[1] + bjets[2]).M()
29 (bjets[1] + bjets[3]).M()
30 (bjets[2] + bjets[3]).M()
31 (bjets[0] + leptons_tot + MET).Mt()
32 (bjets[1] + leptons_tot + MET).Mt()
33 (bjets[2] + leptons_tot + MET).Mt()
34 (bjets[3] + leptons_tot + MET).Mt()
35 (jets[0] + jets[1]).M()
36 jets[0].Pt()
37 jets[1].Pt()
38 jets[0].DeltaR(jets[1])
39 bjets[0].DeltaR(leptons_tot)
40 bjets[1].DeltaR(leptons_tot)
41 bjets[2].DeltaR(leptons_tot)
42 bjets[3].DeltaR(leptons_tot)
43 bjets[0].DeltaPhi(leptons_tot)
44 bjets[1].DeltaPhi(leptons_tot)
45 bjets[2].DeltaPhi(leptons_tot)
46 bjets[3].DeltaPhi(leptons_tot)
"""
# Out:
# '\n0 bjets[0].Pt()\n1 bjets[1].Pt()\n2 bjets[2].Pt()\n3 bjets[3].Pt()\n4 (bjets[0].Eta() - bjets[1].Eta())\n5 (bjets[0].Eta() - bjets[2].Eta())\n6 (bjets[0].Eta() - bjets[3].Eta())\n7 (bjets[1].Eta() - bjets[2].Eta())\n8 (bjets[1].Eta() - bjets[3].Eta())\n9 (bjets[2].Eta() - bjets[3].Eta())\n10 bjets[0].DeltaPhi(bjets[1])\n11 bjets[0].DeltaPhi(bjets[2])\n12 bjets[0].DeltaPhi(bjets[3])\n13 bjets[1].DeltaPhi(bjets[2])\n14 bjets[1].DeltaPhi(bjets[3])\n15 bjets[2].DeltaPhi(bjets[3])\n16 bjets[0].DeltaR(bjets[1])\n17 bjets[0].DeltaR(bjets[2])\n18 bjets[0].DeltaR(bjets[3])\n19 bjets[1].DeltaR(bjets[2])\n20 bjets[1].DeltaR(bjets[3])\n21 bjets[2].DeltaR(bjets[3])\n22 MET.Pt()\n23 np.sum(np.array(leptons)).Pt()\n24 (leptons_tot + MET).Mt()\n25 (bjets[0] + bjets[1]).M()\n26 (bjets[0] + bjets[2]).M()\n27 (bjets[0] + bjets[3]).M()\n28 (bjets[1] + bjets[2]).M()\n29 (bjets[1] + bjets[3]).M()\n30 (bjets[2] + bjets[3]).M()\n31 (bjets[0] + leptons_tot + MET).Mt()\n32 (bjets[1] + leptons_tot + MET).Mt
# ...

# %%
import matplotlib.pyplot as plt 

significance_350_gb = [9.124, 9.315, 9.307, 9.377, 9.194, 8.87, 6.988,8.163]
significance_1000_gb = [0.964, 1.049, 1.033, 0.96, 0.945, 1.145, 1.288, 1.01]
significance_3000_gb = [0.031, 0.029, 0.028, 0.052, 2.252, 2.251, 0.019, 0.036]
significance_350_lr = [8.546, 8.478, 8.557, 8.507, 8.525, 8.517, 8.443, 8.609]
significance_1000_lr = [2.696, 0.159, 1.588, 2.241, 0.376, 1.608, 2.083, 1.899]
significance_3000_lr = [1.532, 2.003, 1.473, 1.119, 1.959, 0.774, 0.802, 2.01]
variables = [8,10,12,14,16,18,19,20]

plt.figure(figsize=(15,10))
plt.plot(variables, significance_350_gb, label="GB. 350 GeV")
plt.plot(variables, significance_1000_gb, label="GB. 1000 GeV")
plt.plot(variables, significance_3000_gb, label="GB. 3000 GeV")
plt.plot(variables, significance_350_lr, label="LR. 350 GeV")
plt.plot(variables, significance_1000_lr, label="LR. 1000 GeV")
plt.plot(variables, significance_3000_lr, label="LR. 3000 GeV")
plt.title("Significance vs number of maximal features")
plt.legend()
plt.xlabel("Number of maximal variables")
plt.ylabel("Significance")
plt.yscale("log")
